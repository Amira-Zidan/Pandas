# %%
import pandas as pd
import numpy as np

# %%
data={
    'Name': ['Ahmed', ' Sara', 'Ahmed', 'Mona', 'khaled '],
    'Age': [25, 22, 25, np.nan, 200],
    'City': ['Cairo', 'Dubai', 'Cairo', 'DUBAI', 'Riyadh'],
    'Salary': ['5000', '7000', '5000', 'missing', '4000']}
df=pd.DataFrame(data)
df
# Out:
#       Name    Age    City   Salary
# 0    Ahmed   25.0   Cairo     5000
# 1     Sara   22.0   Dubai     7000
# 2    Ahmed   25.0   Cairo     5000
# 3     Mona    NaN   DUBAI  missing
# 4  khaled   200.0  Riyadh     4000

# %%
df['City']=df['City'].str.strip().str.capitalize()
df
# Out:
#       Name    Age    City   Salary
# 0    Ahmed   25.0   Cairo     5000
# 1     Sara   22.0   Dubai     7000
# 2    Ahmed   25.0   Cairo     5000
# 3     Mona    NaN   Dubai  missing
# 4  khaled   200.0  Riyadh     4000

# %%
df.fillna(0, inplace=True)
# Out:
#       Name    Age    City   Salary
# 0    Ahmed   25.0   Cairo     5000
# 1     Sara   22.0   Dubai     7000
# 2    Ahmed   25.0   Cairo     5000
# 3     Mona    0.0   Dubai  missing
# 4  khaled   200.0  Riyadh     4000

# %%
df['Name']=df['Name'].str.strip().str.upper()
df
# Out:
#      Name    Age    City   Salary
# 0   AHMED   25.0   Cairo     5000
# 1    SARA   22.0   Dubai     7000
# 2   AHMED   25.0   Cairo     5000
# 3    MONA    0.0   Dubai  missing
# 4  KHALED  200.0  Riyadh     4000

# %%
df['Age']=df['Age'].astype(int)
df
# Out:
#      Name  Age    City   Salary
# 0   AHMED   25   Cairo     5000
# 1    SARA   22   Dubai     7000
# 2   AHMED   25   Cairo     5000
# 3    MONA    0   Dubai  missing
# 4  KHALED  200  Riyadh     4000

# %%
df.loc[df['Age']>100, 'Age'] = df['Age'].median()
df
# Out:
#      Name   Age    City   Salary
# 0   AHMED  25.0   Cairo     5000
# 1    SARA  22.0   Dubai     7000
# 2   AHMED  25.0   Cairo     5000
# 3    MONA   NaN   Dubai  missing
# 4  KHALED  25.0  Riyadh     4000

# %%
df['Salary']=pd.to_numeric(df['Salary'], errors='coerce')
df
# Out:
#      Name  Age    City  Salary
# 0   AHMED   25   Cairo  5000.0
# 1    SARA   22   Dubai  7000.0
# 2   AHMED   25   Cairo  5000.0
# 3    MONA    0   Dubai     NaN
# 4  KHALED  200  Riyadh  4000.0

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#      Name  Age    City  Salary
# 0   AHMED   25   Cairo  5000.0
# 1    SARA   22   Dubai  7000.0
# 2   AHMED   25   Cairo  5000.0
# 3    MONA    0   Dubai  5250.0
# 4  KHALED  200  Riyadh  4000.0

# %%
df['Salary'] = df['Salary'].apply(lambda x: "{:,.0f}".format(x))
df
# Out:
#      Name  Age    City Salary
# 0   AHMED   25   Cairo  5,000
# 1    SARA   22   Dubai  7,000
# 2   AHMED   25   Cairo  5,000
# 3    MONA    0   Dubai  5,250
# 4  KHALED  200  Riyadh  4,000

# %%
df['Age'] = df['Age'].replace(0, df['Age'].median())
df
# Out:
#      Name  Age    City Salary
# 0   AHMED   25   Cairo  5,000
# 1    SARA   22   Dubai  7,000
# 2   AHMED   25   Cairo  5,000
# 3    MONA   25   Dubai  5,250
# 4  KHALED  200  Riyadh  4,000
