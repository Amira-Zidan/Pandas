# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Z:\Downloads\Ice Cream Ratings.csv",index_col ='Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot( )
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot( ylabel = 'Flavor Rating',title ='Flavor Rating' , c= 'red')
# Out:
# <Axes: title={'center': 'Flavor Rating'}, xlabel='Date', ylabel='Flavor Rating'>

# %%
df.plot.barh(subplots = True)
# Out:
# array([<Axes: title={'center': 'Flavor Rating'}, ylabel='Date'>,
#        <Axes: title={'center': 'Texture Rating'}, ylabel='Date'>,
#        <Axes: title={'center': 'Overall Rating'}, ylabel='Date'>],
#       dtype=object)

# %%
df['Flavor Rating'].plot.barh(xlabel = 'Flavor Rating',title = 'Flavor Rating')
# Out:
# <Axes: title={'center': 'Flavor Rating'}, xlabel='Flavor Rating', ylabel='Date'>

# %%
df.plot.scatter(x = 'Flavor Rating' , y = 'Overall Rating',s = 20 ,c = 'green', title = 'rating' )
# Out:
# <Axes: title={'center': 'rating'}, xlabel='Flavor Rating', ylabel='Overall Rating'>

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Flavor Rating'].plot.hist(x = 'Date')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot(figsize = (10,5))
# Out:
# <Axes: >

# %%
df.reset_index()
# Out:
#        Date  Flavor Rating  Texture Rating  Overall Rating
# 0  1/1/2022       0.223090        0.040220        0.600129
# 1  1/2/2022       0.635886        0.938476        0.106264
# 2  1/3/2022       0.442323        0.044154        0.598112
# 3  1/4/2022       0.389128        0.549676        0.489353
# 4  1/5/2022       0.386887        0.519439        0.988280
# 5  1/6/2022       0.877984        0.193588        0.832827
# 6  1/7/2022       0.140995        0.325110        0.105147
