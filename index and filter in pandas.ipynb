# %%
import pandas as pd

# %%
df = pd.read_csv(r"Z:\Downloads\Flavors.csv", index_col = 'Base Flavor')

# %%
df
# Out:
#                              Flavor Liked  Flavor Rating  Texture Rating  \
# Base Flavor
# Vanilla         Mint Chocolate Chip   Yes           10.0             8.0
# Chocolate                 Chocolate   Yes            8.8             7.6
# Vanilla                     Vanilla    No            4.7             5.0
# Vanilla                Cookie Dough   Yes            6.9             6.5
# Chocolate                Rocky Road   Yes            8.2             7.0
# Vanilla                   Pistachio    No            2.3             3.4
# Vanilla                 Cake Batter   Yes            6.5             6.0
# Vanilla                  Neapolitan    No            3.8             5.0
# Chocolate    Chocolte Fudge Brownie   Yes            8.2             7.1
#
#              Total Rating
# Base Flavor
# Vanilla              18.0
# Chocolate            16.6
# Vanilla               9.7
# Vanilla              13.4
# Chocolate            15.2
# Vanilla               5.7
# ...

# %%
df.loc['Chocolate']
# Out:
#                              Flavor Liked  Flavor Rating  Texture Rating  \
# Base Flavor
# Chocolate                 Chocolate   Yes            8.8             7.6
# Chocolate                Rocky Road   Yes            8.2             7.0
# Chocolate    Chocolte Fudge Brownie   Yes            8.2             7.1
#
#              Total Rating
# Base Flavor
# Chocolate            16.6
# Chocolate            15.2
# Chocolate            15.3

# %%
df.iloc[2]
# Out:
# Flavor            Vanilla
# Liked                  No
# Flavor Rating         4.7
# Texture Rating        5.0
# Total Rating          9.7
# Name: Vanilla, dtype: object

# %%
df
# Out:
#                              Flavor Liked  Flavor Rating  Texture Rating  \
# Base Flavor
# Vanilla         Mint Chocolate Chip   Yes           10.0             8.0
# Chocolate                 Chocolate   Yes            8.8             7.6
# Vanilla                     Vanilla    No            4.7             5.0
# Vanilla                Cookie Dough   Yes            6.9             6.5
# Chocolate                Rocky Road   Yes            8.2             7.0
# Vanilla                   Pistachio    No            2.3             3.4
# Vanilla                 Cake Batter   Yes            6.5             6.0
# Vanilla                  Neapolitan    No            3.8             5.0
# Chocolate    Chocolte Fudge Brownie   Yes            8.2             7.1
#
#              Total Rating
# Base Flavor
# Vanilla              18.0
# Chocolate            16.6
# Vanilla               9.7
# Vanilla              13.4
# Chocolate            15.2
# Vanilla               5.7
# ...

# %%
df.reset_index(inplace = True)

# %%
df.set_index(['Base Flavor' , 'Flavor'],inplace = True)

# %%
df
# Out:
#                                    Liked  Flavor Rating  Texture Rating  \
# Base Flavor Flavor
# Vanilla     Mint Chocolate Chip      Yes           10.0             8.0
# Chocolate   Chocolate                Yes            8.8             7.6
# Vanilla     Vanilla                   No            4.7             5.0
#             Cookie Dough             Yes            6.9             6.5
# Chocolate   Rocky Road               Yes            8.2             7.0
# Vanilla     Pistachio                 No            2.3             3.4
#             Cake Batter              Yes            6.5             6.0
#             Neapolitan                No            3.8             5.0
# Chocolate   Chocolte Fudge Brownie   Yes            8.2             7.1
#
#                                     Total Rating
# Base Flavor Flavor
# Vanilla     Mint Chocolate Chip             18.0
# Chocolate   Chocolate                       16.6
# Vanilla     Vanilla                          9.7
# ...

# %%
df.sort_index(ascending= [False,True] , inplace = True)
df
# Out:
#                                    Liked  Flavor Rating  Texture Rating  \
# Base Flavor Flavor
# Vanilla     Cake Batter              Yes            6.5             6.0
#             Cookie Dough             Yes            6.9             6.5
#             Mint Chocolate Chip      Yes           10.0             8.0
#             Neapolitan                No            3.8             5.0
#             Pistachio                 No            2.3             3.4
#             Vanilla                   No            4.7             5.0
# Chocolate   Chocolate                Yes            8.8             7.6
#             Chocolte Fudge Brownie   Yes            8.2             7.1
#             Rocky Road               Yes            8.2             7.0
#
#                                     Total Rating
# Base Flavor Flavor
# Vanilla     Cake Batter                     12.5
#             Cookie Dough                    13.4
#             Mint Chocolate Chip             18.0
# ...

# %%
df.loc['Vanilla']
# Out:
#                     Liked  Flavor Rating  Texture Rating  Total Rating
# Flavor
# Cake Batter           Yes            6.5             6.0          12.5
# Cookie Dough          Yes            6.9             6.5          13.4
# Mint Chocolate Chip   Yes           10.0             8.0          18.0
# Neapolitan             No            3.8             5.0           8.8
# Pistachio              No            2.3             3.4           5.7
# Vanilla                No            4.7             5.0           9.7

# %%
df.iloc[1]
# Out:
# Liked              Yes
# Flavor Rating      6.9
# Texture Rating     6.5
# Total Rating      13.4
# Name: (Vanilla, Cookie Dough), dtype: object

# %%
df.loc['Vanilla','Pistachio']
# Out:
# Liked              No
# Flavor Rating     2.3
# Texture Rating    3.4
# Total Rating      5.7
# Name: (Vanilla, Pistachio), dtype: object

# %%
df.iloc[4]
# Out:
# Liked              No
# Flavor Rating     2.3
# Texture Rating    3.4
# Total Rating      5.7
# Name: (Vanilla, Pistachio), dtype: object

# %%
df
# Out:
#                                    Liked  Flavor Rating  Texture Rating  \
# Base Flavor Flavor
# Chocolate   Chocolate                Yes            8.8             7.6
#             Chocolte Fudge Brownie   Yes            8.2             7.1
#             Rocky Road               Yes            8.2             7.0
# Vanilla     Cake Batter              Yes            6.5             6.0
#             Cookie Dough             Yes            6.9             6.5
#             Mint Chocolate Chip      Yes           10.0             8.0
#             Neapolitan                No            3.8             5.0
#             Pistachio                 No            2.3             3.4
#             Vanilla                   No            4.7             5.0
#
#                                     Total Rating
# Base Flavor Flavor
# Chocolate   Chocolate                       16.6
#             Chocolte Fudge Brownie          15.3
#             Rocky Road                      15.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Flavor          9 non-null      object
#  1   Base Flavor     9 non-null      object
#  2   Liked           9 non-null      object
#  3   Flavor Rating   9 non-null      float64
#  4   Texture Rating  9 non-null      float64
#  5   Total Rating    9 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 564.0+ bytes

# %%
df.set_index('Base Flavor')
# Out:
#              level_0  index                  Flavor Liked  Flavor Rating  \
# Base Flavor
# Vanilla            0      0     Mint Chocolate Chip   Yes           10.0
# Chocolate          1      1               Chocolate   Yes            8.8
# Vanilla            2      2                 Vanilla    No            4.7
# Vanilla            3      3            Cookie Dough   Yes            6.9
# Chocolate          4      4              Rocky Road   Yes            8.2
# Vanilla            5      5               Pistachio    No            2.3
# Vanilla            6      6             Cake Batter   Yes            6.5
# Vanilla            7      7              Neapolitan    No            3.8
# Chocolate          8      8  Chocolte Fudge Brownie   Yes            8.2
#
#              Texture Rating  Total Rating
# Base Flavor
# Vanilla                 8.0          18.0
# Chocolate               7.6          16.6
# Vanilla                 5.0           9.7
# ...
