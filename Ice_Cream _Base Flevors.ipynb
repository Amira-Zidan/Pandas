# %%
import pandas as pd

# %%
df = pd.read_csv(r"Z:\Downloads\Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.set_index("Flavor",inplace=True)
df
# Out:
#                        Base Flavor Liked  Flavor Rating  Texture Rating  \
# Flavor
# Mint Chocolate Chip        Vanilla   Yes           10.0             8.0
# Chocolate                Chocolate   Yes            8.8             7.6
# Vanilla                    Vanilla    No            4.7             5.0
# Cookie Dough               Vanilla   Yes            6.9             6.5
# Rocky Road               Chocolate   Yes            8.2             7.0
# Pistachio                  Vanilla    No            2.3             3.4
# Cake Batter                Vanilla   Yes            6.5             6.0
# Neapolitan                 Vanilla    No            3.8             5.0
# Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#                         Total Rating
# Flavor
# Mint Chocolate Chip             18.0
# Chocolate                       16.6
# Vanilla                          9.7
# Cookie Dough                    13.4
# Rocky Road                      15.2
# ...

# %%
df.sort_index(ascending=False,inplace=True)
df
# Out:
#                        Base Flavor Liked  Flavor Rating  Texture Rating  \
# Flavor
# Vanilla                    Vanilla    No            4.7             5.0
# Rocky Road               Chocolate   Yes            8.2             7.0
# Pistachio                  Vanilla    No            2.3             3.4
# Neapolitan                 Vanilla    No            3.8             5.0
# Mint Chocolate Chip        Vanilla   Yes           10.0             8.0
# Cookie Dough               Vanilla   Yes            6.9             6.5
# Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
# Chocolate                Chocolate   Yes            8.8             7.6
# Cake Batter                Vanilla   Yes            6.5             6.0
#
#                         Total Rating
# Flavor
# Vanilla                          9.7
# Rocky Road                      15.2
# Pistachio                        5.7
# Neapolitan                       8.8
# Mint Chocolate Chip             18.0
# ...

# %%
df.loc["Chocolate"]
# Out:
# Base Flavor       Chocolate
# Liked                   Yes
# Flavor Rating           8.8
# Texture Rating          7.6
# Total Rating           16.6
# Name: Chocolate, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.set_index(["Base Flavor","Flavor"],inplace=True)
df
# Out:
#                                    Liked  Flavor Rating  Texture Rating  \
# Base Flavor Flavor
# Vanilla     Vanilla                   No            4.7             5.0
# Chocolate   Rocky Road               Yes            8.2             7.0
# Vanilla     Pistachio                 No            2.3             3.4
#             Neapolitan                No            3.8             5.0
#             Mint Chocolate Chip      Yes           10.0             8.0
#             Cookie Dough             Yes            6.9             6.5
# Chocolate   Chocolte Fudge Brownie   Yes            8.2             7.1
#             Chocolate                Yes            8.8             7.6
# Vanilla     Cake Batter              Yes            6.5             6.0
#
#                                     Total Rating
# Base Flavor Flavor
# Vanilla     Vanilla                          9.7
# Chocolate   Rocky Road                      15.2
# Vanilla     Pistachio                        5.7
# ...

# %%
df.sort_index(ascending=[False,True],inplace=True)
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                    Liked  Flavor Rating  Texture Rating  \
# Base Flavor Flavor
# Vanilla     Cake Batter              Yes            6.5             6.0
#             Cookie Dough             Yes            6.9             6.5
#             Mint Chocolate Chip      Yes           10.0             8.0
#             Neapolitan                No            3.8             5.0
#             Pistachio                 No            2.3             3.4
#             Vanilla                   No            4.7             5.0
# Chocolate   Chocolate                Yes            8.8             7.6
#             Chocolte Fudge Brownie   Yes            8.2             7.1
#             Rocky Road               Yes            8.2             7.0
#
#                                     Total Rating
# Base Flavor Flavor
# Vanilla     Cake Batter                     12.5
#             Cookie Dough                    13.4
#             Mint Chocolate Chip             18.0
# ...

# %%
df.drop(columns="Texture Rating",inplace=True)

# %%
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Total Rating
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0          18.0
# 1               Chocolate   Chocolate   Yes            8.8          16.6
# 2                 Vanilla     Vanilla    No            4.7           9.7
# 3            Cookie Dough     Vanilla   Yes            6.9          13.4
# 4              Rocky Road   Chocolate   Yes            8.2          15.2
# 5               Pistachio     Vanilla    No            2.3           5.7
# 6             Cake Batter     Vanilla   Yes            6.5          12.5
# 7              Neapolitan     Vanilla    No            3.8           8.8
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2          15.3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df.reset_index(inplace=True)
df
# Out:
#    index                  Flavor Base Flavor Liked  Flavor Rating  \
# 0      0     Mint Chocolate Chip     Vanilla   Yes           10.0
# 1      1               Chocolate   Chocolate   Yes            8.8
# 2      2                 Vanilla     Vanilla    No            4.7
# 3      3            Cookie Dough     Vanilla   Yes            6.9
# 4      4              Rocky Road   Chocolate   Yes            8.2
# 5      5               Pistachio     Vanilla    No            2.3
# 6      6             Cake Batter     Vanilla   Yes            6.5
# 7      7              Neapolitan     Vanilla    No            3.8
# 8      8  Chocolte Fudge Brownie   Chocolate   Yes            8.2
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.set_index("Base Flavor",inplace=True)    
df
# Out:
#                              Flavor Liked  Flavor Rating  Total Rating
# Base Flavor
# Vanilla                 Cake Batter   Yes            6.5          12.5
# Vanilla                Cookie Dough   Yes            6.9          13.4
# Vanilla         Mint Chocolate Chip   Yes           10.0          18.0
# Vanilla                  Neapolitan    No            3.8           8.8
# Vanilla                   Pistachio    No            2.3           5.7
# Vanilla                     Vanilla    No            4.7           9.7
# Chocolate                 Chocolate   Yes            8.8          16.6
# Chocolate    Chocolte Fudge Brownie   Yes            8.2          15.3
# Chocolate                Rocky Road   Yes            8.2          15.2

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
df.groupby(["Base Flavor","Flavor","Liked"]).mean().plot.barh()
# Out:
# <Axes: ylabel='Base Flavor,Flavor,Liked'>

# %%
df.groupby(["Base Flavor","Flavor","Liked"]).mean()
# Out:
#                                           index  Flavor Rating  Total Rating
# Base Flavor Flavor                 Liked
# Chocolate   Chocolate              Yes      1.0            8.8          16.6
#             Chocolte Fudge Brownie Yes      8.0            8.2          15.3
#             Rocky Road             Yes      4.0            8.2          15.2
# Vanilla     Cake Batter            Yes      6.0            6.5          12.5
#             Cookie Dough           Yes      3.0            6.9          13.4
#             Mint Chocolate Chip    Yes      0.0           10.0          18.0
#             Neapolitan             No       7.0            3.8           8.8
#             Pistachio              No       5.0            2.3           5.7
#             Vanilla                No       2.0            4.7           9.7

# %%
df_grouped = df.groupby(["Base Flavor", "Flavor", "Liked"]).mean().reset_index()
df_grouped
# Out:
#   Base Flavor                  Flavor Liked  Flavor Rating  Total Rating
# 0   Chocolate               Chocolate   Yes            8.8          16.6
# 1   Chocolate  Chocolte Fudge Brownie   Yes            8.2          15.3
# 2   Chocolate              Rocky Road   Yes            8.2          15.2
# 3     Vanilla             Cake Batter   Yes            6.5          12.5
# 4     Vanilla            Cookie Dough   Yes            6.9          13.4
# 5     Vanilla     Mint Chocolate Chip   Yes           10.0          18.0
# 6     Vanilla              Neapolitan    No            3.8           8.8
# 7     Vanilla               Pistachio    No            2.3           5.7
# 8     Vanilla                 Vanilla    No            4.7           9.7

# %%
df_grouped.plot(kind="bar", x="Base Flavor", y=["Flavor Rating", "Total Rating"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_grouped.plot(kind="bar", x="Base Flavor", y=["Flavor Rating", "Total Rating"])
#
# NameError: name 'df_grouped' is not defined

# %%
df_grouped.plot(kind="bar", x="Base Flavor", y=["Flavor Rating", "Total Rating"], figsize=(10, 5))
# Out:
# <Axes: xlabel='Base Flavor'>

# %%
df1 = df[['Base Flavor', 'Flavor Rating','Total Rating']]
df1
# Out:
#   Base Flavor  Flavor Rating  Total Rating
# 0     Vanilla           10.0          18.0
# 1   Chocolate            8.8          16.6
# 2     Vanilla            4.7           9.7
# 3     Vanilla            6.9          13.4
# 4   Chocolate            8.2          15.2
# 5     Vanilla            2.3           5.7
# 6     Vanilla            6.5          12.5
# 7     Vanilla            3.8           8.8
# 8   Chocolate            8.2          15.3

# %%
df2=df1.groupby('Base Flavor').mean()
df2
# Out:
#              Flavor Rating  Total Rating
# Base Flavor
# Chocolate              8.4         15.70
# Vanilla                5.7         11.35

# %%
df2.reset_index().plot.barh(x='Base Flavor', y=['Total Rating', 'Flavor Rating'], color=['red', 'blue'], figsize=(10, 5))
# Out:
# <Axes: ylabel='Base Flavor'>

# %%
df2.reset_index().plot.bar(x='Base Flavor', y=['Total Rating', 'Flavor Rating'], color=['green', 'blue'], figsize=(10, 5))
# Out:
# <Axes: xlabel='Base Flavor'>

# %%
df2.reset_index().plot.bar(x='Base Flavor', y=['Total Rating', 'Flavor Rating'], color=['green', 'blue'], figsize=(10, 5))
plt.title('Average Ratings by Base Flavor')
plt.xlabel('Base Flavor')
plt.ylabel('Average Rating')
plt.show()
